# %%
import pandas as pd
import numpy as np
from keras.datasets import mnist
import gradio as gr
import tensorflow as tf
from tensorflow import keras 
from keras import Sequential
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D
from tensorflow.keras.callbacks import EarlyStopping as ES
import matplotlib.pyplot as mp
from sklearn.preprocessing import StandardScaler as SS
from keras.models import Model

# %%
(xta, yta), (xte, yte) = mnist.load_data()

# %%
xta.shape
# Out:
# (60000, 28, 28)

# %%
f,a=mp.subplots(4,4,figsize=(10,8))
for i in range(4):
    for j in range(4):
        a[i][j].imshow(xta[i+j].reshape(28,28))

# %%
xta=xta/255
xte=xte/255

# %%
model=Sequential()
model.add(Conv2D(20,kernel_size=(3,3),padding="same",activation="relu",input_shape=(28,28,1)))
model.add(MaxPool2D(pool_size=(2, 2),strides=2))

model.add(Conv2D(40,kernel_size=(3,3),padding="same",activation="relu"))
model.add(MaxPool2D(pool_size=(2, 2),strides=2))

model.add(Flatten())
model.add(Dense(20,activation="relu"))
model.add(Dense(10,activation="softmax"))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 20)        200
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 20)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 40)        7240
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 40)         0
#  2D)
#
#  flatten (Flatten)           (None, 1960)              0
#
#  dense (Dense)               (None, 20)                39220
#
#  dense_1 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 46,870
# Trainable params: 46,870
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(momentum=0.8,nesterov=True),loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
es=ES(monitor="val_loss",
    min_delta=0.001,
    patience=2,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
    start_from_epoch=0,)

# %%
model.fit(xta,yta,validation_data=(xte,yte),epochs=10,batch_size=20,callbacks=es)
# Out:
# Epoch 1/10
# 3000/3000 [==============================] - 17s 6ms/step - loss: 0.1913 - accuracy: 0.9399 - val_loss: 0.0623 - val_accuracy: 0.9794
# Epoch 2/10
# 3000/3000 [==============================] - 17s 6ms/step - loss: 0.0633 - accuracy: 0.9806 - val_loss: 0.0423 - val_accuracy: 0.9865
# Epoch 3/10
# 3000/3000 [==============================] - 17s 6ms/step - loss: 0.0464 - accuracy: 0.9856 - val_loss: 0.0456 - val_accuracy: 0.9853
# Epoch 4/10
# 2994/3000 [============================>.] - ETA: 0s - loss: 0.0370 - accuracy: 0.9886Restoring model weights from the end of the best epoch: 2.
# 3000/3000 [==============================] - 17s 6ms/step - loss: 0.0371 - accuracy: 0.9887 - val_loss: 0.0429 - val_accuracy: 0.9854
# Epoch 4: early stopping

# %% [markdown]
# # Layer 1

# %%
visual=Model(inputs=model.inputs,outputs=model.layers[0].output)
fm=visual.predict(xte[0].reshape(1,28,28,1))
f,a=mp.subplots(5,5,figsize=(10,10))
for i in range(5):
    for j in range(5):
        a[i,j].imshow(fm[:,:,:,i+j].reshape(28,28),cmap="gray");
# Out:
# 1/1 [==============================] - 0s 55ms/step

# %% [markdown]
# # Layer 2

# %%
visual_2=Model(inputs=model.inputs,outputs=model.layers[1].output)
fm_2=visual_2.predict(xte[0].reshape(1,28,28,1))
f,a=mp.subplots(5,5,figsize=(10,10))
for i in range(5):
    for j in range(5):
        a[i,j].imshow(fm_2[:,:,:,i+j].reshape(14,14),cmap="gray");
# Out:
# 1/1 [==============================] - 0s 27ms/step

# %% [markdown]
# # Layer 3

# %%
visual_2=Model(inputs=model.inputs,outputs=model.layers[2].output)
fm_2=visual_2.predict(xte[0].reshape(1,28,28,1))
f,a=mp.subplots(5,5,figsize=(10,10))
for i in range(5):
    for j in range(5):
        a[i,j].imshow(fm_2[:,:,:,i+j].reshape(14,14),cmap="gray");
# Out:
# 1/1 [==============================] - 0s 33ms/step

# %% [markdown]
# # Layer 4

# %%
visual_2=Model(inputs=model.inputs,outputs=model.layers[3].output)
fm_2=visual_2.predict(xte[0].reshape(1,28,28,1))
f,a=mp.subplots(5,5,figsize=(10,10))
for i in range(5):
    for j in range(5):
        a[i,j].imshow(fm_2[:,:,:,i+j].reshape(7,7),cmap="gray");
# Out:
# 1/1 [==============================] - 0s 34ms/step

# %%
def ghh(jk):
    return model.predict(jk.reshape(1,28,28)).argmax()
sk=gr.Sketchpad(shape=(28,28),tool="color-sketch")
gr.Interface(fn=ghh,inputs=sk,outputs="text",live=True).launch();
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000284F7EA5C60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 49ms/step
